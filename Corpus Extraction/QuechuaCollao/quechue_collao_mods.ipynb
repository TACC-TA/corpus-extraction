# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/Script.xlsx - ABURRIDO.csv')
df2 = pd.read_csv('/content/Script.xlsx - ADORMILADO.csv')
df3 = pd.read_csv('/content/Script.xlsx - CALMADO.csv')
df4 = pd.read_csv('/content/Script.xlsx - EMOCIONADO.csv')
df5 = pd.read_csv('/content/Script.xlsx - ENOJADO.csv')
df6 = pd.read_csv('/content/Script.xlsx - FELIZ.csv')
df7 = pd.read_csv('/content/Script.xlsx - NEUTRAL.csv')
df8 = pd.read_csv('/content/Script.xlsx - TEMEROSO.csv')
df9 = pd.read_csv('/content/Script.xlsx - TRISTE.csv')

dfs = [df1,df2,df3,df4,df5,df6,df7,df8,df9]
sents = ['ABURRIDO','ADORMILADO','CALMADO','EMOCIONADO','ENOJADO','FELIZ','NEUTRAL','TEMEROSO','TRISTE',]

# %%
dfs[0].head()
# Out:
#      ID  N°     Tipo  T Quechua  Traducción (español)
# 0  B001   1  Palabra  W  Ch’arwi             Desorden
# 1  B002   2  Palabra  W     Runa              Persona
# 2  B003   3  Palabra  W   Chanin               Precio
# 3  B004   4  Palabra  W     Puka                 Rojo
# 4  B005   5  Palabra  W  Hallp’a               Tierra

# %%
for i in range(len(dfs)):
  dfs[i]['Sentimiento'] = sents[i]

# %%
dfs[1].head()
# Out:
#      ID  N°     Tipo  T Quechua  Traducción (español) Sentimiento
# 0  S001   1  Palabra  W    Chiri                 Frío  ADORMILADO
# 1  S002   2  Palabra  W   Chuchu                 Duro  ADORMILADO
# 2  S003   3  Palabra  W  Lliklla                Manta  ADORMILADO
# 3  S004   4  Palabra  W   Wist´u                 Cojo  ADORMILADO
# 4  S005   5  Palabra  W  Llant´a                 Leña  ADORMILADO

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.tail()
# Out:
#         ID   N°     Tipo  T  \
# 2066  T226  226  Oración  S
# 2067  T227  227  Oración  S
# 2068  T228  228  Oración  S
# 2069  T229  229  Oración  S
# 2070  T230  230  Oración  S
#
#                                                Quechua   \
# 2066  Runakuna manan mallkikunata tarpunkuchu chaymi...
# 2067                  Erqe mamanpa wañusqanmanta waqan.
# 2068  Huk wayna chakamanta wukchuyukusqa hinaspa wañ...
# 2069   Mama churin mana wasinman kutimusqanmanta waqan.
# 2070     Erqe anchata karru alqonta saruruqtin waqasqa.
#
#                                    Traducción (español) Sentimiento
# 2066  La personas no plantan árboles es uno de los f...      TRISTE
# 2067               El niño llora porque su madre murió.      TRISTE
# 2068              Un joven se lanzó del puente y murió.      TRISTE
# 2069  La madre llora porque su hijo no vuelve a la c...      TRISTE
# 2070  El niño lloró mucho porque el carro lo atropel...      TRISTE

# %%
df.to_csv('QuechuaCollaoCorpus.csv', index=False)
